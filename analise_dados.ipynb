# %% [markdown]
# <a href="https://colab.research.google.com/github/prinakayama/DataGirls_Desafio_dados/blob/master/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importação das bibliotecas**

# %%
import pandas as pd

# %% [markdown]
# ## Importação do Dataset e o armazenamento do conteúdo em um DataFrame

# %%
dados = pd.read_csv('/content/State_of_data_BR_2023_Kaggle - df_survey_2023.csv')

# %% [markdown]
# ## Visualização do conteúdo do DataFrame

# %%
dados.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1  0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3  00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9                  34
#
#   ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                      30-34           Masculino                      Branca
# 1                      30-34           Masculino                      Branca
# 2                      35-39            Feminino                     Amarela
# 3                      22-24           Masculino                       Preta
# 4                      30-34           Masculino                      Branca
#
#   ('P1_d ', 'PCD')  ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0              Não                                                NaN
# ...
